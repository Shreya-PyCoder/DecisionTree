# %%
import pandas as pd

# %%
A=pd.read_csv("F:/data science workshop/DATA-SET/data/Cars93.csv")

# %%
A.head()
# Out:
#    Unnamed: 0 Manufacturer    Model     Type  Min.Price  Price  Max.Price  \
# 0           1        Acura  Integra    Small       12.9   15.9       18.8
# 1           2        Acura   Legend  Midsize       29.2   33.9       38.7
# 2           3         Audi       90  Compact       25.9   29.1       32.3
# 3           4         Audi      100  Midsize       30.8   37.7       44.6
# 4           5          BMW     535i  Midsize       23.7   30.0       36.2
#
#    MPG.city  MPG.highway             AirBags  ... Passengers Length  \
# 0        25           31                None  ...          5    177
# 1        18           25  Driver & Passenger  ...          5    195
# 2        20           26         Driver only  ...          5    180
# 3        19           26  Driver & Passenger  ...          6    193
# 4        22           30         Driver only  ...          4    186
#
#    Wheelbase  Width  Turn.circle  Rear.seat.room Luggage.room  Weight  \
# ...

# %%
A=A.drop(labels="Unnamed: 0",axis=1)

# %%
A.head()
# Out:
#   Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0        Acura  Integra    Small       12.9   15.9       18.8        25
# 1        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2         Audi       90  Compact       25.9   29.1       32.3        20
# 3         Audi      100  Midsize       30.8   37.7       44.6        19
# 4          BMW     535i  Midsize       23.7   30.0       36.2        22
#
#    MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# 0           31                None      Front  ...          5     177
# 1           25  Driver & Passenger      Front  ...          5     195
# 2           26         Driver only      Front  ...          5     180
# 3           26  Driver & Passenger      Front  ...          6     193
# 4           30         Driver only       Rear  ...          4     186
#
#    Wheelbase  Width  Turn.circle Rear.seat.room  Luggage.room  Weight  \
# ...

# %%
import seaborn as sb

# %%
import matplotlib.pyplot as plt

# %%
A.columns
# Out:
# Index(['Manufacturer', 'Model', 'Type', 'Min.Price', 'Price', 'Max.Price',
#        'MPG.city', 'MPG.highway', 'AirBags', 'DriveTrain', 'Cylinders',
#        'EngineSize', 'Horsepower', 'RPM', 'Rev.per.mile', 'Man.trans.avail',
#        'Fuel.tank.capacity', 'Passengers', 'Length', 'Wheelbase', 'Width',
#        'Turn.circle', 'Rear.seat.room', 'Luggage.room', 'Weight', 'Origin',
#        'Make'],
#       dtype='object')

# %%
Y=A[["Type"]]
X=A[['Manufacturer', 'Model', 'Type', 'Min.Price', 'Price', 'Max.Price',
       'MPG.city', 'MPG.highway', 'AirBags', 'DriveTrain', 'Cylinders',
       'EngineSize', 'Horsepower', 'RPM', 'Rev.per.mile', 'Man.trans.avail',
       'Fuel.tank.capacity', 'Passengers', 'Length', 'Wheelbase', 'Width',
       'Turn.circle', 'Rear.seat.room', 'Luggage.room', 'Weight', 'Origin',
       'Make']]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
le=LabelEncoder()

# %%
X=X.apply(le.fit_transform)

# %%
X
# Out:
#     Manufacturer  Model  Type  Min.Price  Price  Max.Price  MPG.city  \
# 0              0     48     3         25     33         36        10
# 1              0     55     2         67     71         73         3
# 2              1      8     0         63     66         63         5
# 3              1      0     2         69     76         76         4
# 4              2      5     2         61     68         69         7
# ..           ...    ...   ...        ...    ...        ...       ...
# 88            30     41     5         42     47         49         2
# 89            30     64     0         46     50         47         6
# 90            30     28     4         60     57         51         3
# 91            31      2     0         57     56         50         6
# 92            31      7     2         62     63         59         5
#
#     MPG.highway  AirBags  DriveTrain  ...  Passengers  Length  Wheelbase  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(X,Y,test_size=0.2,random_state=10)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc=DecisionTreeClassifier(criterion='entropy',random_state=30,max_depth=7)

# %%
model=dtc.fit(xtrain,ytrain)

# %%
pred=model.predict(xtest)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
accuracy_score(ytest,pred)
# Out:
# 1.0

# %%
confusion_matrix(ytest,pred)
# Out:
# array([[1, 0, 0, 0, 0],
#        [0, 8, 0, 0, 0],
#        [0, 0, 4, 0, 0],
#        [0, 0, 0, 5, 0],
#        [0, 0, 0, 0, 1]], dtype=int64)

# %%
dtc=DecisionTreeClassifier(criterion='entropy')

# %%
from sklearn.model_selection import GridSearchCV

# %%
tp={"max_depth":range(2,15)}

# %%
gcv=GridSearchCV(dtc,tp,scoring="accuracy",cv=4)

# %%
cvmodel=gcv.fit(xtrain,ytrain)
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)

# %%
cvmodel.best_params_
# Out:
# {'max_depth': 9}
